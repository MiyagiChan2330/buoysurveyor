# %%
import folium
import geopandas as gpd

# %%
shapefile_IR = 'shapefiles_pd2/International_Routes_Batangas.shp'
gdf = gpd.read_file(shapefile_IR)
gdf.head()
# Out:
#                     GM_LAYER                    GM_TYPE                 NAME  \
# 0  Unclassified Line Feature  Unclassified Line Feature  Verde Passage Route
# 1  Unclassified Line Feature  Unclassified Line Feature           NW Mindoro
#
#                        LAYER     LENGTH        BEARING  \
# 0  Unclassified Line Feature  544.55 km  114° 30' 8.2"
# 1  Unclassified Line Feature  63.991 km  50° 34' 10.8"
#
#                                             geometry
# 0  LINESTRING (120.54182 14.25864, 120.53543 13.8...
# 1  LINESTRING (120.11513 13.46895, 120.17929 13.5...

# %%
gdf = gdf[['NAME','LENGTH','BEARING','geometry']].fillna(0)
gdf.head()
# Out:
#                   NAME     LENGTH        BEARING  \
# 0  Verde Passage Route  544.55 km  114° 30' 8.2"
# 1           NW Mindoro  63.991 km  50° 34' 10.8"
#
#                                             geometry
# 0  LINESTRING (120.54182 14.25864, 120.53543 13.8...
# 1  LINESTRING (120.11513 13.46895, 120.17929 13.5...

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
