# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import folium

# %%
shapefile_RR = 'shapefiles_pd2/Roro_Routes_Batangas.shp'
gdf = gpd.read_file(shapefile_RR)
gdf.head()
# Out:
#                        NAME              LAYER   KML_FOLDER  \
# 0   Batangas - Abra de Ilog  Unknown Line Type  RoRo Routes
# 1  Batangas - Puerto Galera  Unknown Line Type  RoRo Routes
# 2        Batangas - Romblon  Unknown Line Type  RoRo Routes
# 3        Batangas - Calapan  Unknown Line Type  RoRo Routes
# 4       Batangas - San Jose  Unknown Line Type  RoRo Routes
#
#                                             geometry
# 0  LINESTRING (121.04089 13.75383, 120.97820 13.6...
# 1  LINESTRING (120.93346 13.50671, 120.94965 13.5...
# 2  LINESTRING (122.26884 12.57846, 122.25289 12.6...
# 3  LINESTRING (121.19459 13.42932, 121.01988 13.5...
# 4  LINESTRING (121.08816 12.33119, 121.08838 12.3...

# %%
gdf = gdf[['NAME','KML_FOLDER','geometry']].fillna(0)
gdf.head()
# Out:
#                        NAME   KML_FOLDER  \
# 0   Batangas - Abra de Ilog  RoRo Routes
# 1  Batangas - Puerto Galera  RoRo Routes
# 2        Batangas - Romblon  RoRo Routes
# 3        Batangas - Calapan  RoRo Routes
# 4       Batangas - San Jose  RoRo Routes
#
#                                             geometry
# 0  LINESTRING (121.04089 13.75383, 120.97820 13.6...
# 1  LINESTRING (120.93346 13.50671, 120.94965 13.5...
# 2  LINESTRING (122.26884 12.57846, 122.25289 12.6...
# 3  LINESTRING (121.19459 13.42932, 121.01988 13.5...
# 4  LINESTRING (121.08816 12.33119, 121.08838 12.3...

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
